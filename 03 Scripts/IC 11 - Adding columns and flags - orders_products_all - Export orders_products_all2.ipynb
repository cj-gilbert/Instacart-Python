# %% [markdown]
# # Table of Contents

# %% [markdown]
# 0.1 Importing Libraries
#
# 0.2 Importing Data
#
# 0.3 Exploring Original Df
#
# 0.4 Create new columns
#
#     0.4.1  region
#
#     0.4.2  low_activity_flag
#
#     0.4.3  total_spent_in_order
#
#     0.4.4  total_spent_in_lifetime
#
#     0.4.5  total_items_in_lifetime
#
#     0.4.6  avg_items_per_order_by_user
#
# 0.5 Confirming Final Df
#
# 0.6 Exporting Final Df

# %% [markdown]
# ### 0.1 Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 0.2 Importing Data

# %%
# Identify the file pathway to data files
path = r'C:\Users\CJ\Documents\_CJ-Stuff\Career Foundry\Data Immersion\Ach 4 - Python\2023-03 Instacart Basket Analysis'

# %%
# Import data
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_all.pkl'))

# %% [markdown]
# ### 0.3 Exploring Original Df

# %%
df.shape
# Out:
# (32434489, 33)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order_of_new_customer  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered  ... spender_type  median_days_since_ordering  \
# 0                  1          0  ...  Low spender                        20.0
# 1                  2          0  ...  Low spender                        20.0
# 2                  3          0  ...  Low spender                        20.0
# 3                  4          0  ...  Low spender                        20.0
# 4                  5          0  ...  Low spender                        20.0
#
#    frequent_shopper  gender    state  age date_joined n_dependants fam_status  \
# 0  Regular customer  Female  Alabama   31  2019-02-17            3    married
# 1  Regular customer  Female  Alabama   31  2019-02-17            3    married
# 2  Regular customer  Female  Alabama   31  2019-02-17            3    married
# 3  Regular customer  Female  Alabama   31  2019-02-17            3    married
# 4  Regular customer  Female  Alabama   31  2019-02-17            3    married
#
#   income
# 0  40423
# 1  40423
# 2  40423
# 3  40423
# 4  40423
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 33 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   order_id                     int64
#  1   user_id                      int64
#  2   order_number                 int16
#  3   order_day_of_week            int8
#  4   order_hour_of_day            int8
#  5   days_since_prior_order       float16
#  6   first_order_of_new_customer  bool
#  7   product_id                   int32
#  8   add_to_cart_order            int16
#  9   reordered                    int8
#  10  product_name                 object
#  11  aisle_id                     float16
#  12  department_id                float16
#  13  price                        float32
#  14  product_info_available       bool
#  15  price_available              bool
#  16  price_range                  category
#  17  busiest_day                  category
#  18  busiest_days                 category
#  19  busiest_period_of_day        category
#  20  max_order                    int16
#  21  loyalty_flag                 category
#  22  mean_spending                float32
#  23  spender_type                 category
#  24  median_days_since_ordering   float16
#  25  frequent_shopper             category
#  26  gender                       category
#  27  state                        category
#  28  age                          int16
#  29  date_joined                  datetime64[ns]
#  30  n_dependants                 int8
#  31  fam_status                   category
#  32  income                       int64
# dtypes: bool(3), category(10), datetime64[ns](1), float16(4), float32(2), int16(4), int32(1), int64(3), int8(4), object(1)
# memory usage: 2.8+ GB

# %%
# Checking for nulls
df.isnull().sum()
# Out:
# order_id                             0
# user_id                              0
# order_number                         0
# order_day_of_week                    0
# order_hour_of_day                    0
# days_since_prior_order         2078068
# first_order_of_new_customer          0
# product_id                           0
# add_to_cart_order                    0
# reordered                            0
# product_name                     30770
# aisle_id                         30770
# department_id                    30770
# price                            35897
# product_info_available               0
# price_available                      0
# price_range                      35897
# busiest_day                          0
# busiest_days                         0
# busiest_period_of_day                0
# max_order                            0
# loyalty_flag                         0
# mean_spending                        0
# spender_type                         0
# median_days_since_ordering           0
# frequent_shopper                     0
# gender                               0
# state                                0
# age                                  0
# date_joined                          0
# n_dependants                         0
# fam_status                           0
# income                               0
# dtype: int64

# %%
# The null values for days_since_prior_order 
# are flagged by first_order of new customer
df['first_order_of_new_customer'].value_counts()
# Out:
# False    30356421
# True      2078068
# Name: first_order_of_new_customer, dtype: int64

# %%
# The null values for price
# are flagged by price_available
df['price_available'].value_counts()
# Out:
# True     32398592
# False       35897
# Name: price_available, dtype: int64

# %%
# The null values for product_name, aisle_id, and department_id 
# are flagged by product_info_available
df['product_info_available'].value_counts()
# Out:
# True     32403719
# False       30770
# Name: product_info_available, dtype: int64

# %% [markdown]
# All null/NaN values are appropriately flagged.

# %% [markdown]
# ###     0.4.1 region

# %%
# Create lists for each region

# %%
northeast = ['Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'Pennsylvania', 'New Jersey']

# %%
midwest = ['Wisconsin', 'Michigan', 'Illinois', 'Indiana', 'Ohio', 'North Dakota', 'South Dakota', 'Nebraska', 'Kansas', 'Minnesota', 'Iowa', 'Missouri']

# %%
south = ['Delaware', 'Maryland', 'District of Columbia', 'Virginia', 'West Virginia', 'North Carolina', 'South Carolina', 'Georgia', 'Florida', 'Kentucky', 'Tennessee', 'Mississippi', 'Alabama', 'Oklahoma', 'Texas', 'Arkansas', 'Louisiana']

# %%
west = ['Idaho', 'Montana', 'Wyoming', 'Nevada', 'Utah', 'Colorado', 'Arizona', 'New Mexico', 'Alaska', 'Washington', 'Oregon', 'California', 'Hawaii']

# %%
# Assign a region to go with each state value

result = []

for value in df["state"]:
  if value in northeast:
    result.append("Northeast")
  elif value in midwest:
    result.append("Midwest")
  elif value in south:
    result.append("South")
  elif value in west:
    result.append("West")
  else:
    result.append("Unknown region")

# %%
# Explore result of loop
result
# Out:
# ['South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'South',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  'West',
#  ...]

# %%
# Append the results of the loop to the df
df['region'] = result

# %%
# Confirming the data in 'region'
df['region'].value_counts(dropna = False)
# Out:
# South        10801796
# West          8300481
# Midwest       7603861
# Northeast     5728351
# Name: region, dtype: int64

# %%
df[['state', 'region']].head()
# Out:
#      state region
# 0  Alabama  South
# 1  Alabama  South
# 2  Alabama  South
# 3  Alabama  South
# 4  Alabama  South

# %%
df.shape
# Out:
# (32434489, 34)

# %%
# Reclaiming memory
del result

# %% [markdown]
# ### 0.4.2  low_activity_flag

# %%
# Calculating the number of low_activity rows
len(df[df['max_order']<5])
# Out:
# 1441523

# %%
# Creating a column 'low_activity_flag' with values based 
# on if max_order is < 5, then TRUE
#    else FALSE
df['low_activity_flag'] = df['max_order']<5

# %%
# Checking the data
df['low_activity_flag'].value_counts(dropna = False)
# Out:
# False    30992966
# True      1441523
# Name: low_activity_flag, dtype: int64

# %%
df[['max_order', 'low_activity_flag']].head()
# Out:
#    max_order  low_activity_flag
# 0         10              False
# 1         10              False
# 2         10              False
# 3         10              False
# 4         10              False

# %%
df.shape
# Out:
# (32434489, 35)

# %%
# Per customer request (CF instructions), we are exporting a copy of the df
# with only data from customers with >=5 orders

df_subset = df[df['low_activity_flag'] == False]

# %%
# Checking subset
df_subset.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order_of_new_customer  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered  ...  frequent_shopper  gender    state  age  \
# 0                  1          0  ...  Regular customer  Female  Alabama   31
# 1                  2          0  ...  Regular customer  Female  Alabama   31
# 2                  3          0  ...  Regular customer  Female  Alabama   31
# 3                  4          0  ...  Regular customer  Female  Alabama   31
# 4                  5          0  ...  Regular customer  Female  Alabama   31
#
#    date_joined  n_dependants fam_status income region low_activity_flag
# 0   2019-02-17             3    married  40423  South             False
# 1   2019-02-17             3    married  40423  South             False
# 2   2019-02-17             3    married  40423  South             False
# 3   2019-02-17             3    married  40423  South             False
# 4   2019-02-17             3    married  40423  South             False
#
# [5 rows x 35 columns]

# %%
# Confirming subset has correct number of rows
df_subset.shape
# Out:
# (30992966, 35)

# %%
#Exporting subset df
df_subset.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_5_plus.pkl'))

# %%
# Reclaiming memory
del df_subset

# %% [markdown]
# ### 0.4.3  total_spent_in_order

# %%
# Create a new column 'total_spent_in_order'
# By first grouping data by order_id, then
# appling the transform() function to the prices column
# with the np.sum argument
df['total_spent_in_order'] = df.groupby(['order_id'])['price'].transform(np.sum)

# %%
# Confirming the column was created correctly
df[['order_id', 'price', 'total_spent_in_order']].head(20)
# Out:
#     order_id  price  total_spent_in_order
# 0    2539329    9.0             31.600000
# 1    2539329   12.5             31.600000
# 2    2539329    4.4             31.600000
# 3    2539329    4.7             31.600000
# 4    2539329    1.0             31.600000
# 5    2398795    9.0             35.400002
# 6    2398795    3.0             35.400002
# 7    2398795    4.4             35.400002
# 8    2398795   10.3             35.400002
# 9    2398795    4.7             35.400002
# 10   2398795    4.0             35.400002
# 11    473747    9.0             28.200001
# 12    473747    4.4             28.200001
# 13    473747    3.0             28.200001
# 14    473747    8.6             28.200001
# 15    473747    3.2             28.200001
# 16   2254736    9.0             26.000000
# 17   2254736    4.4             26.000000
# 18   2254736    3.0             26.000000
# 19   2254736    8.6             26.000000

# %%
df.shape
# Out:
# (32434489, 36)

# %% [markdown]
# ### 0.4.4 total_spent_in_lifetime

# %%
# Create a new column 'total_spent_in_lifetime'
# By first grouping data by user_id, then
# appling the transform() function to the prices column
# with the np.sum argument
df['total_spent_in_lifetime'] = df.groupby(['user_id'])['price'].transform(np.sum)

# %%
# Confirming the column was created correctly
df[['user_id', 'order_id', 'price', 'total_spent_in_lifetime']].head(100)
# Out:
#     user_id  order_id  price  total_spent_in_lifetime
# 0         1   2539329    9.0               375.700012
# 1         1   2539329   12.5               375.700012
# 2         1   2539329    4.4               375.700012
# 3         1   2539329    4.7               375.700012
# 4         1   2539329    1.0               375.700012
# ..      ...       ...    ...                      ...
# 95        2    738281    5.9              1465.599976
# 96        2   1673511   14.0              1465.599976
# 97        2   1673511    2.9              1465.599976
# 98        2   1673511    1.6              1465.599976
# 99        2   1673511    3.4              1465.599976
#
# [100 rows x 4 columns]

# %%
df.shape
# Out:
# (32434489, 37)

# %% [markdown]
# ###     0.4.5  total_items_in_lifetime

# %%
# Identifying the number of unique users
df['user_id'].nunique()
# Out:
# 206209

# %%
# Confirming the range of user_ids
df['user_id'].min()
# Out:
# 1

# %%
# Confirming the range of user_ids
df['user_id'].max()
# Out:
# 206209

# %%
# Creating a temporary dataframe to hold the number of items
# purchased by each user
df_items = pd.DataFrame()

# %%
df_items['total_items_in_lifetime'] = df['user_id'].value_counts().sort_index()

# %%
df_items.head()
# Out:
#    total_items_in_lifetime
# 1                       59
# 2                      195
# 3                       88
# 4                       18
# 5                       37

# %%
df_items.shape
# Out:
# (206209, 1)

# %%
# Exploring totals
df_items.describe()
# Out:
#        total_items_in_lifetime
# count            206209.000000
# mean                157.289396
# std                 204.208233
# min                   3.000000
# 25%                  39.000000
# 50%                  83.000000
# 75%                 188.000000
# max                3725.000000

# %%
# Making the user_id for each row explicit
df_items['user_id'] = df_items.index

# %%
df_items['user_id'].max()
# Out:
# 206209

# %%
df_items['user_id'].min()
# Out:
# 1

# %%
df_items.shape
# Out:
# (206209, 2)

# %%
df_items.head()
# Out:
#    total_items_in_lifetime  user_id
# 1                       59        1
# 2                      195        2
# 3                       88        3
# 4                       18        4
# 5                       37        5

# %%
# Merging total_items_in_lifetime with full df
df = df.merge(df_items, on = ['user_id'], how = 'left', indicator = True)

# %%
# Exploring the merge
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order_of_new_customer  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered  ... date_joined  n_dependants  fam_status  \
# 0                  1          0  ...  2019-02-17             3     married
# 1                  2          0  ...  2019-02-17             3     married
# 2                  3          0  ...  2019-02-17             3     married
# 3                  4          0  ...  2019-02-17             3     married
# 4                  5          0  ...  2019-02-17             3     married
#
#    income  region  low_activity_flag total_spent_in_order  \
# 0   40423   South              False                 31.6
# 1   40423   South              False                 31.6
# 2   40423   South              False                 31.6
# 3   40423   South              False                 31.6
# 4   40423   South              False                 31.6
#
#   total_spent_in_lifetime total_items_in_lifetime _merge
# 0              375.700012                      59   both
# 1              375.700012                      59   both
# 2              375.700012                      59   both
# 3              375.700012                      59   both
# 4              375.700012                      59   both
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (32434489, 39)

# %% [markdown]
# The shape is what we would expect: same number of rows, columns increased by 2 (the new column plus the merge field)

# %%
df['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Removing the merge flag so it doesn't interfere with future merges
df = df.drop(columns = ['_merge'])

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order_of_new_customer  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered  ... age  date_joined  n_dependants  \
# 0                  1          0  ...  31   2019-02-17             3
# 1                  2          0  ...  31   2019-02-17             3
# 2                  3          0  ...  31   2019-02-17             3
# 3                  4          0  ...  31   2019-02-17             3
# 4                  5          0  ...  31   2019-02-17             3
#
#    fam_status  income  region low_activity_flag total_spent_in_order  \
# 0     married   40423   South             False                 31.6
# 1     married   40423   South             False                 31.6
# 2     married   40423   South             False                 31.6
# 3     married   40423   South             False                 31.6
# 4     married   40423   South             False                 31.6
#
#   total_spent_in_lifetime total_items_in_lifetime
# 0              375.700012                      59
# 1              375.700012                      59
# 2              375.700012                      59
# 3              375.700012                      59
# 4              375.700012                      59
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (32434489, 38)

# %% [markdown]
# ### 0.4.6 avg_items_per_order_by_user

# %%
# Create a column with the avg_items_per_order_by_user
df['avg_items_per_order_by_user'] = df['total_items_in_lifetime'] / df['max_order']

# %%
# Explore new column
df['avg_items_per_order_by_user'].describe()
# Out:
# count    3.243449e+07
# mean     1.318593e+01
# std      6.547892e+00
# min      1.000000e+00
# 25%      8.535354e+00
# 50%      1.200000e+01
# 75%      1.657143e+01
# max      7.025000e+01
# Name: avg_items_per_order_by_user, dtype: float64

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order_of_new_customer  product_id  \
# 0                     NaN                         True         196
# 1                     NaN                         True       14084
# 2                     NaN                         True       12427
# 3                     NaN                         True       26088
# 4                     NaN                         True       26405
#
#    add_to_cart_order  reordered  ... date_joined  n_dependants  fam_status  \
# 0                  1          0  ...  2019-02-17             3     married
# 1                  2          0  ...  2019-02-17             3     married
# 2                  3          0  ...  2019-02-17             3     married
# 3                  4          0  ...  2019-02-17             3     married
# 4                  5          0  ...  2019-02-17             3     married
#
#    income  region  low_activity_flag total_spent_in_order  \
# 0   40423   South              False                 31.6
# 1   40423   South              False                 31.6
# 2   40423   South              False                 31.6
# 3   40423   South              False                 31.6
# 4   40423   South              False                 31.6
#
#   total_spent_in_lifetime total_items_in_lifetime avg_items_per_order_by_user
# 0              375.700012                      59                         5.9
# 1              375.700012                      59                         5.9
# 2              375.700012                      59                         5.9
# 3              375.700012                      59                         5.9
# 4              375.700012                      59                         5.9
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (32434489, 39)

# %% [markdown]
# ### 0.5 Confirming Final Df

# %%
df.shape
# Out:
# (32434489, 39)

# %% [markdown]
# Final df has expected number of rows (32434489) and columns (33+4).

# %%
# Checking datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 39 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   order_id                     int64
#  1   user_id                      int64
#  2   order_number                 int16
#  3   order_day_of_week            int8
#  4   order_hour_of_day            int8
#  5   days_since_prior_order       float16
#  6   first_order_of_new_customer  bool
#  7   product_id                   int32
#  8   add_to_cart_order            int16
#  9   reordered                    int8
#  10  product_name                 object
#  11  aisle_id                     float16
#  12  department_id                float16
#  13  price                        float32
#  14  product_info_available       bool
#  15  price_available              bool
#  16  price_range                  category
#  17  busiest_day                  category
#  18  busiest_days                 category
#  19  busiest_period_of_day        category
#  20  max_order                    int16
#  21  loyalty_flag                 category
#  22  mean_spending                float32
#  23  spender_type                 category
#  24  median_days_since_ordering   float16
#  25  frequent_shopper             category
#  26  gender                       category
#  27  state                        category
#  28  age                          int16
#  29  date_joined                  datetime64[ns]
#  30  n_dependants                 int8
#  31  fam_status                   category
#  32  income                       int64
#  33  region                       object
#  34  low_activity_flag            bool
#  35  total_spent_in_order         float32
#  36  total_spent_in_lifetime      float32
#  37  total_items_in_lifetime      int64
#  38  avg_items_per_order_by_user  float64
# dtypes: bool(4), category(10), datetime64[ns](1), float16(4), float32(4), float64(1), int16(4), int32(1), int64(4), int8(4), object(2)
# memory usage: 3.8+ GB

# %%
# Adjust datatypes for new columns to be more appropriately sized
df['region'] = df['region'].astype('category')
df['total_items_in_lifetime'] = df['total_items_in_lifetime'].astype('int32')
df['avg_items_per_order_by_user'] = df['avg_items_per_order_by_user'].astype('float16')

# %%
# Confirming changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 39 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   order_id                     int64
#  1   user_id                      int64
#  2   order_number                 int16
#  3   order_day_of_week            int8
#  4   order_hour_of_day            int8
#  5   days_since_prior_order       float16
#  6   first_order_of_new_customer  bool
#  7   product_id                   int32
#  8   add_to_cart_order            int16
#  9   reordered                    int8
#  10  product_name                 object
#  11  aisle_id                     float16
#  12  department_id                float16
#  13  price                        float32
#  14  product_info_available       bool
#  15  price_available              bool
#  16  price_range                  category
#  17  busiest_day                  category
#  18  busiest_days                 category
#  19  busiest_period_of_day        category
#  20  max_order                    int16
#  21  loyalty_flag                 category
#  22  mean_spending                float32
#  23  spender_type                 category
#  24  median_days_since_ordering   float16
#  25  frequent_shopper             category
#  26  gender                       category
#  27  state                        category
#  28  age                          int16
#  29  date_joined                  datetime64[ns]
#  30  n_dependants                 int8
#  31  fam_status                   category
#  32  income                       int64
#  33  region                       category
#  34  low_activity_flag            bool
#  35  total_spent_in_order         float32
#  36  total_spent_in_lifetime      float32
#  37  total_items_in_lifetime      int32
#  38  avg_items_per_order_by_user  float16
# dtypes: bool(4), category(11), datetime64[ns](1), float16(5), float32(4), int16(4), int32(2), int64(3), int8(4), object(1)
# memory usage: 3.3+ GB

# %% [markdown]
# ### 0.6 Exporting the new df

# %%
#Exporting final df
df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_all2.pkl'))
